# %%
Z = {}
for i, s in enumerate(['_weighted', '_unweighted']):
    figure()
    try:
        d = loadtxt('data/grid10000' + s + '.dat')
    except:
        continue
    x = unique(d[:, 0])
    y = unique(d[:, 1])
    X, Y = meshgrid(x, y)
    z = d[:,2] # * (1 - d[:,0]) # rescale
    #z = d[:, 2]
    
    Z[i] = reshape(z,(len(x), -1))
    print(shape(X),shape(Y),shape(Z))
    pcolor(X,Y,transpose(Z[i]))
    c = colorbar()

    c.set_label("$t$")
    xlabel("$\phi$")
    ylabel("$\eta$")
    xlim([0, 0.5])
    clim([7, 11])
    savefig("test.pdf")
    
figure()
pcolor(X,Y,transpose(Z[0] - Z[1]))
colorbar()
# Out:
# ((19, 2), (19, 2), ())
# ((19, 19), (19, 19), ())
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-8f68230b1280> in <module>()
#      25
#      26 figure()
# ---> 27 pcolor(X,Y,transpose(Z[0] - Z[1]))
#      28 colorbar()
#
# ValueError: operands could not be broadcast together with shapes (2,19) (19,19)

# %%
tfor i, phi in enumerate([0.1,0.5,0.9]):
    figure(i)
    for eta in [0.1,0.5,0.9]:
        try:
            ts = loadtxt('data/ecdf_phi{0}_eta{1}.dat'.format(phi,eta))
        except:
            continue
        #ts = ts * (1.0 - phi)
        runs = len(ts)
        c = 1.0/runs
        ecdf = []
        for t in ts:
            ecdf.append(c)
            c += 1.0/runs
        
        semilogx(ts,ecdf,label='$\phi={0},\eta={1}$'.format(phi,eta)) 

    axis('tight')
    axis([1, 1000, None, None])
    legend(loc='lower right')
    xlabel('t')
    ylabel('ECDF')
    savefig('fig/ecdf_phi{0}.pdf'.format(phi))

# %%
figsize(5,4)
for phi in [0.1, 0.5, 0.9]:
    figure()
    for eta in [0.1, 0.3, 0.5, 0.7,0.9]:
        d = loadtxt('data/ddist_phi{0}_eta{1}_n10000.dat'.format(phi, eta))
        d = d[1:] / sum(d)
        loglog(range(1,len(d)+1), d, 'x:', label='$\eta={0}$'.format(eta))
    legend(loc='best')
    xlabel('degree')
    ylabel('fraction')
    xlim(1,40)
    #axis('tight')
    ylim(0.0005, 0.35)
    tit = 'Degree distribution for $\phi={0}$'.format(phi)
    title(tit)
    savefig("fig/Deg_Dist_phi{0}.pdf".format(phi).replace(".","_",1))

# %%
figsize(5,4)
for phi in [0.1, 0.5]:
    figure()
    for eta in [0.1, 0.3, 0.5, 0.7,0.9]:
        try:
            d = loadtxt('data/ddist_type_phi{0}_eta{1}_n10000.dat'.format(phi, eta))
        except:
            continue                
        d = d[:,1:]
        for row in d:
            row /= sum(row)
        loglog(range(1,len(d[0,:])+1), d[0,:], 'x:', label='heterophilic $\eta={0}$'.format(eta))
        loglog(range(1,len(d[1,:])+1), d[1,:], 'o:', label='homophiclic $\eta={0}$'.format(eta))
    #legend(loc='right outside')
    xlabel('degree')
    ylabel('fraction')
    #xlim(1,40)
    #axis('tight')
    #ylim(0.0005, 0.35)
    tit = 'Degree distribution for $\phi={0}$'.format(phi)
    title(tit)
    savefig("fig/Deg_Dist_Type_phi{0}.pdf".format(phi).replace(".","_",1))
